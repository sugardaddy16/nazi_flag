# %%
# !pip install ColabTurtlePlus
import ColabTurtlePlus.Turtle as t
t.clearscreen()
t.setup(250, 150)
t.setworldcoordinates(-125, -75, 125, 75)
t.speed(10)
t.penup()
t.goto(-125, -75)
t.color("red")
t.pendown()
t.begin_fill()
for i in range(2):
    t.forward(250)
    t.left(90)
    t.forward(150)
    t.left(90)
t.end_fill()
t.penup()
t.goto(0, -56.25)
t.color("white")
t.pendown()
t.begin_fill()
t.circle(56.25)
t.end_fill()
t.penup()
t.goto(0, -35.15625 * (2**0.5))
t.left(45)
t.color("black")
t.pendown()
t.begin_fill()
for i in range(4):
    t.forward(42.1875)
    t.left(90)
    t.forward(28.125)
    t.right(90)
    t.forward(14.0625)
    t.right(90)
    t.forward(28.125)
    t.left(90)
    t.forward(14.0625)
    t.left(90)
t.end_fill()
t.penup()
t.ht()
# Out:
# ...
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
#       <svg width="250" height="150">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...
